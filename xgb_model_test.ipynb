# %% [markdown]
# <a href="https://colab.research.google.com/github/oprostep/2024-Spring-DS/blob/main/xgb_model_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/oprostep/2024-Spring-DS.git
# Out:
# fatal: destination path '2024-Spring-DS' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import xgboost as xgb

# Parsing
df = pd.read_csv("/content/2024-Spring-DS/smartphones_manipulated.csv", sep=',')

categorical_features = ['brand_name', 'processor_brand', 'os']
df[categorical_features] = df[categorical_features].astype('category')

# Load the model
model = xgb.XGBRegressor()
model.load_model("/content/2024-Spring-DS/xgb_model.json")

# %%
sample = pd.Series({'brand_name': np.nan,'has_5g': True,'has_nfc': True, 'has_ir_blaster': np.nan, 'processor_brand':np.nan,
                   'num_cores': 8,'processor_speed':3,'battery_capacity': 5000,
                    'fast_charging_available': np.nan, 'fast_charging': np.nan,'ram_capacity': 8,
                    'internal_memory': np.nan, 'screen_size': np.nan, 'refresh_rate': 144, 'num_rear_cameras': np.nan,
                    'num_front_cameras': np.nan, 'os':'android', 'primary_camera_rear': np.nan,
                    'primary_camera_front': np.nan, 'extended_memory_available': np.nan, 'extended_upto':np.nan,
                    'width': np.nan, 'height': np.nan
                   },
            index=['brand_name', 'has_5g', 'has_nfc', 'has_ir_blaster', 'processor_brand',
                   'num_cores', 'processor_speed', 'battery_capacity',
                   'fast_charging_available', 'fast_charging', 'ram_capacity',
                   'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
                   'num_front_cameras', 'os', 'primary_camera_rear',
                   'primary_camera_front', 'extended_memory_available', 'extended_upto',
                   'width', 'height'])

sample_array = pd.DataFrame([sample], columns=sample.index )
sample_array[categorical_features] = sample_array[categorical_features].astype('category')
sample_array
# Out:
#   brand_name  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 0        NaN    True     True             NaN             NaN          8
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0                3              5000                      NaN            NaN
#
#    ...  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0  ...           144               NaN                NaN  android
#
#    primary_camera_rear  primary_camera_front extended_memory_available  \
# 0                  NaN                   NaN                       NaN
#
#    extended_upto  width  height
# 0            NaN    NaN     NaN
#
# [1 rows x 23 columns]

# %%
predicted_price = model.predict(sample_array)[0]
predicted_price
# Out:
# 737.3292

# %%
actual_prices = df[
    (df['has_5g'] == sample['has_5g']) & (df['num_cores']== sample['num_cores']) &
     (df['ram_capacity']== sample['ram_capacity']) & (df['os']==sample['os']) & (df['refresh_rate']==sample['refresh_rate']) &
      ((df['processor_speed']<=sample['processor_speed']-0.2) | (df['processor_speed']>=sample['processor_speed']+0.2)) &
       ((df['battery_capacity']<=sample['battery_capacity']-200) | (df['battery_capacity']>=sample['battery_capacity']+200))]['price']

print(f"Mean: {round(actual_prices.mean(),2)}, std:{round(actual_prices.std(),2)}, Median: {actual_prices.median()}")
# Out:
# Mean: 546.78, std:157.33, Median: 515.88

# %%
df[
    (df['has_5g'] == sample['has_5g']) & (df['num_cores']== sample['num_cores']) &
     (df['ram_capacity']== sample['ram_capacity']) & (df['os']==sample['os']) & (df['refresh_rate']==sample['refresh_rate']) &
      ((df['processor_speed']<=sample['processor_speed']+0.2) | (df['processor_speed']>=sample['processor_speed']-0.2)) &
       ((df['battery_capacity']<=sample['battery_capacity']+200) | (df['battery_capacity']>=sample['battery_capacity']-200))
       ]
# Out:
#      Unnamed: 0 brand_name                                  model   price  \
# 83           97       iqoo                             iQOO 11 5G  719.99
# 86          102   motorola                  Motorola Moto S30 Pro  287.88
# 101         120   motorola                Motorola Edge 30 Pro 5G  419.99
# 160         193   motorola             Motorola Edge 30 Fusion 5G  479.99
# 168         201   motorola                 Motorola Edge 30 Ultra  659.99
# 184         222   motorola  Motorola Edge 30 5G (8GB RAM + 128GB)  299.99
# 192         230       iqoo                         iQOO 11 Pro 5G  707.88
# 249         299     xiaomi    Xiaomi Redmi K50i (8GB RAM + 256GB)  311.99
# 263         316       poco                             POCO X5 GT  359.88
# 274         332     realme       Realme 9 5G SE (8GB RAM + 128GB)  275.98
# 343         418   motorola                  Motorola Moto X30 Pro  503.88
# 374         460      nubia                              Nubia Z50  419.99
# 393         491       poco                          POCO X4 GT 5G  299.88
# 546         678      nubia                       Nubia Z40 Pro 5G  599.88
# 580         724     xiaomi                   Xiaomi Mi 10T Pro 5G  359.99
# 595         743   motorola                    Motorola Edge 40 5G  419.99
# 620         781     realme                       Realme GT Neo 4T  359.99
# 631         796     xiaomi              Xiaomi Redmi K50 Ultra 5G  479.99
# 713         907   motorola             Motorola Moto Edge X30 Pro  719.88
# 756         964   motorola                Motorola Edge 40 Fusion  515.88
# 759         968   motorola                    Motorola ThinkPhone  599.88
# 764         977       poco        POCO X4 GT 5G (8GB RAM + 256GB)  347.88
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 83     True     True           False      snapdragon        8.0
# 86     True    False           False      snapdragon        8.0
# 101    True     True           False      snapdragon        8.0
# 160    True     True           False      snapdragon        8.0
# 168    True     True           False      snapdragon        8.0
# 184    True     True           False      snapdragon        8.0
# 192    True     True            True      snapdragon        8.0
# 249    True    False            True       dimensity        8.0
# 263    True     True            True       dimensity        8.0
# 274    True    False           False      snapdragon        8.0
# 343    True     True           False      snapdragon        8.0
# 374    True     True           False      snapdragon        8.0
# 393    True     True            True       dimensity        8.0
# 546    True     True           False      snapdragon        8.0
# 580    True     True            True      snapdragon        8.0
# 595    True     True           False      snapdragon        8.0
# 620    True    False           False      snapdragon        8.0
# 631    True     True            True      snapdragon        8.0
# 713    True     True           False      snapdragon        8.0
# 756    True     True           False      snapdragon        8.0
# 759    True     True           False      snapdragon        8.0
# 764    True     True            True       dimensity        8.0
#
#      processor_speed  ...    resolution  num_rear_cameras  num_front_cameras  \
# 83              3.20  ...  1440 x 3200                  3                1.0
# 86              2.90  ...  1080 x 2460                  3                1.0
# 101             3.00  ...  1080 x 2400                  3                1.0
# 160             2.90  ...  1080 x 2400                  3                1.0
# 168             3.20  ...  1080 x 2400                  3                1.0
# 184             2.50  ...  1080 x 2400                  3                1.0
# 192             3.20  ...  1440 x 3200                  3                1.0
# 249             2.85  ...  1080 x 2460                  3                1.0
# 263             3.20  ...  1080 x 2400                  3                1.0
# 274             2.40  ...  1080 x 2412                  3                1.0
# 343             3.20  ...  1080 x 2400                  3                1.0
# 374             3.20  ...  1080 x 2400                  3                1.0
# 393             2.85  ...  1080 x 2460                  3                1.0
# 546             3.00  ...  1080 x 2400                  3                1.0
# 580             2.84  ...  1080 x 2400                  3                1.0
# 595             2.36  ...  1080 x 2412                  3                1.0
# 620             3.00  ...  1080 x 2400                  3                1.0
# 631             3.20  ...  1220 x 2712                  3                1.0
# 713             3.20  ...  1080 x 2340                  3                1.0
# 756             3.20  ...  1080 x 2400                  3                1.0
# 759             3.20  ...  1080 x 2400                  3                2.0
# 764             2.85  ...  1080 x 2460                  3                1.0
#
#           os  primary_camera_rear  primary_camera_front  \
# 83   android                 50.0                  16.0
# 86   android                 50.0                  32.0
# 101  android                 50.0                  60.0
# 160  android                 50.0                  32.0
# 168  android                200.0                  60.0
# 184  android                 50.0                  32.0
# 192  android                 50.0                  16.0
# 249  android                 64.0                  16.0
# 263  android                 64.0                  32.0
# 274  android                 48.0                  16.0
# 343  android                200.0                  60.0
# 374  android                 64.0                  16.0
# 393  android                 64.0                  16.0
# 546  android                 64.0                  16.0
# 580  android                108.0                  20.0
# 595  android                 50.0                  32.0
# 620  android                 50.0                  16.0
# 631  android                108.0                  20.0
# 713  android                200.0                  60.0
# 756  android                 50.0                  32.0
# 759  android                 50.0                  32.0
# 764  android                 64.0                  16.0
#
#      extended_memory_available extended_upto  width  height
# 83                       False           NaN   1440    3200
# 86                       False           NaN   1080    2460
# 101                      False           NaN   1080    2400
# 160                      False           NaN   1080    2400
# 168                      False           NaN   1080    2400
# 184                      False           NaN   1080    2400
# 192                      False           NaN   1440    3200
# 249                      False           NaN   1080    2460
# 263                      False           NaN   1080    2400
# 274                       True        1024.0   1080    2412
# 343                      False           NaN   1080    2400
# 374                      False           NaN   1080    2400
# 393                      False           NaN   1080    2460
# 546                      False           NaN   1080    2400
# 580                      False           NaN   1080    2400
# 595                      False           NaN   1080    2412
# 620                      False           NaN   1080    2400
# 631                      False           NaN   1220    2712
# 713                      False           NaN   1080    2340
# 756                      False           NaN   1080    2400
# 759                      False           NaN   1080    2400
# 764                      False           NaN   1080    2460
#
# [22 rows x 27 columns]
