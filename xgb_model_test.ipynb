# %% [markdown]
# <a href="https://colab.research.google.com/github/oprostep/2024-Spring-DS/blob/main/xgb_model_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/oprostep/2024-Spring-DS.git
# Out:
# fatal: destination path '2024-Spring-DS' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import xgboost as xgb

# Parsing
df = pd.read_csv("/content/2024-Spring-DS/smartphones_manipulated.csv", sep=',')

categorical_features = ['brand_name', 'processor_brand', 'os']
df[categorical_features] = df[categorical_features].astype('category')

# Load the model
model = xgb.XGBRegressor()
model.load_model("/content/2024-Spring-DS/xgb_model.json")

# %%
sample = pd.Series({'brand_name': np.nan,'has_5g': True,'has_nfc': True, 'has_ir_blaster': np.nan, 'processor_brand':np.nan,
                   'num_cores': 8,'processor_speed':np.nan,'battery_capacity': 5000,
                    'fast_charging_available': np.nan, 'fast_charging': np.nan,'ram_capacity': 8,
                    'internal_memory': np.nan, 'screen_size': np.nan, 'refresh_rate': np.nan, 'num_rear_cameras': np.nan,
                    'num_front_cameras': np.nan, 'os':'android', 'primary_camera_rear': np.nan,
                    'primary_camera_front': np.nan, 'extended_memory_available': np.nan, 'extended_upto':np.nan,
                    'width': np.nan, 'height': np.nan
                   },
            index=['brand_name', 'has_5g', 'has_nfc', 'has_ir_blaster', 'processor_brand',
                   'num_cores', 'processor_speed', 'battery_capacity',
                   'fast_charging_available', 'fast_charging', 'ram_capacity',
                   'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
                   'num_front_cameras', 'os', 'primary_camera_rear',
                   'primary_camera_front', 'extended_memory_available', 'extended_upto',
                   'width', 'height'])

sample_array = pd.DataFrame([sample], columns=sample.index )
sample_array[categorical_features] = sample_array[categorical_features].astype('category')
sample_array
# Out:
#   brand_name  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 0        NaN    True     True             NaN             NaN          8
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0              NaN              5000                      NaN            NaN
#
#    ...  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0  ...           NaN               NaN                NaN  android
#
#    primary_camera_rear  primary_camera_front extended_memory_available  \
# 0                  NaN                   NaN                       NaN
#
#    extended_upto  width  height
# 0            NaN    NaN     NaN
#
# [1 rows x 23 columns]

# %%
predicted_price = model.predict(sample_array)[0]
predicted_price
# Out:
# 700.7905

# %%
actual_prices = df[
    (df['has_5g'] == sample['has_5g']) & (df['num_cores']== sample['num_cores']) &
     (df['ram_capacity']== sample['ram_capacity']) & (df['os']==sample['os']) & #(df['refresh_rate']==sample['refresh_rate']) &
      #((df['processor_speed']<=sample['processor_speed']-0.2) | (df['processor_speed']>=sample['processor_speed']+0.2)) &
       ((df['battery_capacity']<=sample['battery_capacity']-200) | (df['battery_capacity']>=sample['battery_capacity']+200))]['price']

print(f"Mean: {round(actual_prices.mean(),2)}, std:{round(actual_prices.std(),2)}, Median: {actual_prices.median()}")
# Out:
# Mean: 411.59, std:138.62, Median: 359.99

# %%
df[
    (df['has_5g'] == sample['has_5g']) & (df['num_cores']== sample['num_cores']) &
     (df['ram_capacity']== sample['ram_capacity']) & (df['os']==sample['os']) & #(df['refresh_rate']==sample['refresh_rate']) &
      #((df['processor_speed']<=sample['processor_speed']+0.2) | (df['processor_speed']>=sample['processor_speed']-0.2)) &
       ((df['battery_capacity']<=sample['battery_capacity']+200) | (df['battery_capacity']>=sample['battery_capacity']-200))
       ]
# Out:
#      Unnamed: 0 brand_name                            model   price  has_5g  \
# 6             7     xiaomi    Xiaomi Redmi Note 12 Pro Plus  359.99    True
# 7             8    nothing                  Nothing Phone 1  320.99    True
# 8             9    oneplus               OnePlus Nord 2T 5G  347.99    True
# 10           11       oppo                         Oppo A78  227.99    True
# 15           18    oneplus                   OnePlus 10R 5G  395.99    True
# ..          ...        ...                              ...     ...     ...
# 759         968   motorola              Motorola ThinkPhone  599.88    True
# 760         969     xiaomi                    Xiaomi Civi 3  395.88    True
# 762         975   motorola       Motorola Moto Edge S30 Pro  419.88    True
# 764         977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  347.88    True
# 766         979    samsung           Samsung Galaxy M52s 5G  299.88    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 6      False            True       dimensity        8.0             2.60  ...
# 7       True           False      snapdragon        8.0             2.50  ...
# 8       True           False       dimensity        8.0             3.00  ...
# 10      True           False       dimensity        8.0             2.20  ...
# 15      True           False       dimensity        8.0             2.85  ...
# ..       ...             ...             ...        ...              ...  ...
# 759     True           False      snapdragon        8.0             3.20  ...
# 760     True            True       dimensity        8.0             3.10  ...
# 762    False           False      snapdragon        8.0             3.00  ...
# 764     True            True       dimensity        8.0             2.85  ...
# 766    False           False             NaN        8.0              NaN  ...
#
#        resolution  num_rear_cameras  num_front_cameras       os  \
# 6    1080 x 2400                  3                1.0  android
# 7    1080 x 2400                  2                1.0  android
# 8    1080 x 2400                  3                1.0  android
# 10    720 x 1612                  2                1.0  android
# 15   1080 x 2412                  3                1.0  android
# ..            ...               ...                ...      ...
# 759  1080 x 2400                  3                2.0  android
# 760  1080 x 2400                  3                2.0  android
# 762  1080 x 2460                  3                1.0  android
# 764  1080 x 2460                  3                1.0  android
# 766  1080 x 2400                  3                1.0  android
#
#      primary_camera_rear  primary_camera_front  extended_memory_available  \
# 6                  200.0                  16.0                      False
# 7                   50.0                  16.0                      False
# 8                   50.0                  32.0                      False
# 10                  50.0                   8.0                       True
# 15                  50.0                  16.0                      False
# ..                   ...                   ...                        ...
# 759                 50.0                  32.0                      False
# 760                 64.0                  32.0                      False
# 762                 64.0                  16.0                      False
# 764                 64.0                  16.0                      False
# 766                 64.0                  32.0                       True
#
#     extended_upto  width  height
# 6             NaN   1080    2400
# 7             NaN   1080    2400
# 8             NaN   1080    2400
# 10            NaN    720    1612
# 15            NaN   1080    2412
# ..            ...    ...     ...
# 759           NaN   1080    2400
# 760           NaN   1080    2400
# 762           NaN   1080    2460
# 764           NaN   1080    2460
# 766        1024.0   1080    2400
#
# [220 rows x 27 columns]
